# %% [markdown]
# # Example of how to use torchtrainer with *Cross-Validation*

# %%
from typing import List, Tuple
import pathlib
import random

import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, Subset, DataLoader
from sklearn.model_selection import train_test_split, KFold

# trainer
from torchtrainer import Trainer
# hooks
from torchtrainer import EarlyStopping, NaNStopping, CSVHook

# %%
DEVICE = torch.device("cpu")
BATCH = 10
NSPLIT = 5

SEED = 42

def torch_fix_seed(seed=SEED):
    # Python random
    random.seed(seed)
    # Numpy
    np.random.seed(seed)
    # Pytorch
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.use_deterministic_algorithms = True

torch_fix_seed()

# %% [markdown]
# ## Prepare dataset

# %%
# dummy dataset
x = torch.rand(100, 32)
y = torch.rand(100, 1)

dataset = TensorDataset(x, y)

# %% [markdown]
# ## Prepare model

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(32, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 1)
        )
    def forward(self, x):
        return self.layers(x)
model = Model()

# %% [markdown]
# ## Define Training

# %% [markdown]
# Model training can be easily performed in **only two steps**.
#
#     1. Define one training step. (if necessary, also define one validation step.)
#     2. Define Trainer object in cross validation roop.

# %% [markdown]
# ### 1. Define one training step
# Define a function representing one training step.
# The function should take one `batch` and `model`, and return a list of `loss` and a list of `prediction` in that order.
# One `batch` can handle any data format (ex `dict`, `tuple`).

# %%
# define loss function
loss_fn = torch.nn.L1Loss(reduction="sum")

def train_step(train_batch, model) -> Tuple[List[torch.Tensor]]:
    # get input and output from one batch
    # if necessary, using `to()` method
    x = train_batch[0].to(DEVICE)
    y = train_batch[1].to(DEVICE)
    # prediction
    pred = model(x)
    # calculate loss
    loss = loss_fn(pred, y)
    
    # return list of loss and list of prediction
    return [loss], [pred]

# %%
# Optional: metrics for CSVhook
# metrics get one batch and result list that you define on train_step
# and return List of Tensor
def rmse(batch, result_list) -> List[torch.Tensor]:
    grand_truth = batch[1]
    pred = result_list[0]
    return [torch.sqrt(torch.mean(torch.pow(grand_truth - pred, 2)))]

# %% [markdown]
# ### 2. Define Trainer object in crooss validation roop

# %%
kf = KFold(n_splits=NSPLIT, random_state=SEED, shuffle=True)
save_path = pathlib.Path("./")

scores = []
for fold, (train_index, test_index) in enumerate(kf.split(dataset)):
    print(f"Fold {fold}")
    print("-" * 50)
    
    # data loader
    train_loader = DataLoader(Subset(dataset, train_index), batch_size=BATCH, shuffle=True)
    val_loader = DataLoader(Subset(dataset, test_index), batch_size=BATCH, shuffle=True)
    
    # get model object
    model = Model()

    # define optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

    # Optional: define LR sceduler
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=5)
    
    # you should set save path for each fold
    save_fold_path = save_path.joinpath(f"trainer_{fold}")
    if not save_fold_path.exists():
        save_fold_path.mkdir()
    
    # trainer object
    trainer = Trainer(
        # The best model and the `state_dict` of the last step are automatically saved.
        # last step is saved in checkpoints directory.
        model_path=save_fold_path,

        # PyTorch model
        model=model,

        # training setting
        n_epoch=100,
        device=DEVICE,

        # set loader
        train_loader=train_loader,
        val_loader=val_loader,

        # set List of optimizer
        optimizer_list=[optimizer],

        # Optional: set List of scheduler
        scheduler_list=[scheduler],

        # set List of hooks
        hooks=[
            # early stoppting hooks
            EarlyStopping(10),
            # catch nan of loss
            NaNStopping(),
            # log to csv
            CSVHook(
                log_path=save_fold_path,
                # Optional: you can set any metrics you like other than loss.
                metrics=[
                    rmse
                ],
                # set name of metrics which write on csv file
                metrics_names=["rmse"]
            )
        ]
    )
    
    # Training
    # Just call the train method!
    best = trainer.train(
        batch=BATCH,
        train_step=train_step,
        verbose=True,
    )
    
    # best loss is detached torch.tensor
    scores.append(best)
# Out:
# Fold 0
# --------------------------------------------------
# epoch 1 start
# Training loss:
# 	 0: 0.263
# validation loss:
# 	 0: 0.299
# ----------------------------------------
#
# ----------------------------------------
# Training is stopped by EarlyStopping.
# Training stopped with epoch 1.
# ----------------------------------------
#
# Fold 1
# --------------------------------------------------
# epoch 1 start
# Training loss:
# 	 0: 0.256
# validation loss:
# 	 0: 0.329
# ----------------------------------------
#
# ----------------------------------------
# Training is stopped by EarlyStopping.
# Training stopped with epoch 1.
# ----------------------------------------
#
# Fold 2
# --------------------------------------------------
# epoch 1 start
# Training loss:
# 	 0: 0.261
# validation loss:
# 	 0: 0.282
# model is saved in epoch 1
# ----------------------------------------
# epoch 2 start
# Training loss:
# 	 0: 0.260
# validation loss:
# 	 0: 0.283
# ----------------------------------------
# epoch 3 start
# Training loss:
# 	 0: 0.259
# validation loss:
# 	 0: 0.283
# ----------------------------------------
# epoch 4 start
# Training loss:
# 	 0: 0.257
# validation loss:
# 	 0: 0.283
# ----------------------------------------
# epoch 5 start
# Training loss:
# 	 0: 0.256
# validation loss:
# 	 0: 0.283
# ----------------------------------------
# epoch 6 start
# Training loss:
# 	 0: 0.255
# validation loss:
# 	 0: 0.283
# ----------------------------------------
# epoch 7 start
# Training loss:
# 	 0: 0.255
# validation loss:
# 	 0: 0.283
# ----------------------------------------
# epoch 8 start
# Training loss:
# 	 0: 0.255
# validation loss:
# 	 0: 0.283
# ----------------------------------------
# epoch 9 start
# Training loss:
# 	 0: 0.255
# validation loss:
# 	 0: 0.283
# ----------------------------------------
# epoch 10 start
# Training loss:
# 	 0: 0.254
# validation loss:
# 	 0: 0.282
# ----------------------------------------
# epoch 11 start
# Training loss:
# 	 0: 0.252
# validation loss:
# 	 0: 0.282
# model is saved in epoch 11
# ----------------------------------------
# epoch 12 start
# Training loss:
# 	 0: 0.252
# validation loss:
# 	 0: 0.283
# ----------------------------------------
#
# ----------------------------------------
# Training is stopped by EarlyStopping.
# Training stopped with epoch 12.
# ----------------------------------------
#
# Fold 3
# --------------------------------------------------
# epoch 1 start
# Training loss:
# 	 0: 0.288
# validation loss:
# 	 0: 0.223
# model is saved in epoch 1
# ----------------------------------------
# epoch 2 start
# Training loss:
# 	 0: 0.287
# validation loss:
# 	 0: 0.223
# ----------------------------------------
# epoch 3 start
# Training loss:
# 	 0: 0.287
# validation loss:
# 	 0: 0.223
# ----------------------------------------
# epoch 4 start
# Training loss:
# 	 0: 0.287
# validation loss:
# 	 0: 0.223
# ----------------------------------------
# epoch 5 start
# Training loss:
# 	 0: 0.287
# validation loss:
# 	 0: 0.225
# ----------------------------------------
# epoch 6 start
# Training loss:
# 	 0: 0.286
# validation loss:
# 	 0: 0.225
# ----------------------------------------
# epoch 7 start
# Training loss:
# 	 0: 0.285
# validation loss:
# 	 0: 0.225
# ----------------------------------------
# epoch 8 start
# Training loss:
# 	 0: 0.283
# validation loss:
# 	 0: 0.222
# model is saved in epoch 8
# ----------------------------------------
# epoch 9 start
# Training loss:
# 	 0: 0.281
# validation loss:
# 	 0: 0.220
# model is saved in epoch 9
# ----------------------------------------
# epoch 10 start
# Training loss:
# 	 0: 0.280
# validation loss:
# 	 0: 0.220
# ----------------------------------------
# epoch 11 start
# Training loss:
# 	 0: 0.279
# validation loss:
# 	 0: 0.219
# model is saved in epoch 11
# ----------------------------------------
# epoch 12 start
# Training loss:
# 	 0: 0.278
# validation loss:
# 	 0: 0.219
# model is saved in epoch 12
# ----------------------------------------
# epoch 13 start
# Training loss:
# 	 0: 0.278
# validation loss:
# 	 0: 0.219
# model is saved in epoch 13
# ----------------------------------------
# epoch 14 start
# Training loss:
# 	 0: 0.278
# validation loss:
# 	 0: 0.219
# ----------------------------------------
# epoch 15 start
# Training loss:
# 	 0: 0.278
# validation loss:
# 	 0: 0.217
# model is saved in epoch 15
# ----------------------------------------
# epoch 16 start
# Training loss:
# 	 0: 0.278
# validation loss:
# 	 0: 0.221
# ----------------------------------------
# epoch 17 start
# Training loss:
# 	 0: 0.277
# validation loss:
# 	 0: 0.217
# model is saved in epoch 17
# ----------------------------------------
# epoch 18 start
# Training loss:
# 	 0: 0.275
# validation loss:
# 	 0: 0.217
# ----------------------------------------
# epoch 19 start
# Training loss:
# 	 0: 0.273
# validation loss:
# 	 0: 0.221
# ----------------------------------------
# epoch 20 start
# Training loss:
# 	 0: 0.271
# validation loss:
# 	 0: 0.220
# ----------------------------------------
# epoch 21 start
# Training loss:
# 	 0: 0.270
# validation loss:
# 	 0: 0.219
# ----------------------------------------
# epoch 22 start
# Training loss:
# 	 0: 0.270
# validation loss:
# 	 0: 0.219
# ----------------------------------------
# epoch 23 start
# Training loss:
# 	 0: 0.270
# validation loss:
# 	 0: 0.219
# ----------------------------------------
# epoch 24 start
# Training loss:
# 	 0: 0.270
# validation loss:
# 	 0: 0.219
# ----------------------------------------
# epoch 25 start
# Training loss:
# 	 0: 0.269
# validation loss:
# 	 0: 0.219
# ----------------------------------------
# epoch 26 start
# Training loss:
# 	 0: 0.269
# validation loss:
# 	 0: 0.220
# ----------------------------------------
# epoch 27 start
# Training loss:
# 	 0: 0.267
# validation loss:
# 	 0: 0.219
# ----------------------------------------
# epoch 28 start
# Training loss:
# 	 0: 0.266
# validation loss:
# 	 0: 0.219
# ----------------------------------------
#
# ----------------------------------------
# Training is stopped by EarlyStopping.
# Training stopped with epoch 28.
# ----------------------------------------
#
# Fold 4
# --------------------------------------------------
# epoch 1 start
# Training loss:
# 	 0: 0.269
# validation loss:
# 	 0: 0.241
# model is saved in epoch 1
# ----------------------------------------
# epoch 2 start
# Training loss:
# 	 0: 0.269
# validation loss:
# 	 0: 0.241
# model is saved in epoch 2
# ----------------------------------------
# epoch 3 start
# Training loss:
# 	 0: 0.268
# validation loss:
# 	 0: 0.240
# model is saved in epoch 3
# ----------------------------------------
# epoch 4 start
# Training loss:
# 	 0: 0.268
# validation loss:
# 	 0: 0.240
# ----------------------------------------
# epoch 5 start
# Training loss:
# 	 0: 0.268
# validation loss:
# 	 0: 0.240
# model is saved in epoch 5
# ----------------------------------------
# epoch 6 start
# Training loss:
# 	 0: 0.268
# validation loss:
# 	 0: 0.240
# model is saved in epoch 6
# ----------------------------------------
# epoch 7 start
# Training loss:
# 	 0: 0.267
# validation loss:
# 	 0: 0.239
# model is saved in epoch 7
# ----------------------------------------
# epoch 8 start
# Training loss:
# 	 0: 0.265
# validation loss:
# 	 0: 0.238
# model is saved in epoch 8
# ----------------------------------------
# epoch 9 start
# Training loss:
# 	 0: 0.264
# validation loss:
# 	 0: 0.235
# model is saved in epoch 9
# ----------------------------------------
# epoch 10 start
# Training loss:
# 	 0: 0.262
# validation loss:
# 	 0: 0.236
# ----------------------------------------
# epoch 11 start
# Training loss:
# 	 0: 0.260
# validation loss:
# 	 0: 0.235
# ----------------------------------------
# epoch 12 start
# Training loss:
# 	 0: 0.259
# validation loss:
# 	 0: 0.235
# ----------------------------------------
# epoch 13 start
# Training loss:
# 	 0: 0.258
# validation loss:
# 	 0: 0.235
# ----------------------------------------
# epoch 14 start
# Training loss:
# 	 0: 0.258
# validation loss:
# 	 0: 0.235
# ----------------------------------------
# epoch 15 start
# Training loss:
# 	 0: 0.258
# validation loss:
# 	 0: 0.235
# ----------------------------------------
# epoch 16 start
# Training loss:
# 	 0: 0.258
# validation loss:
# 	 0: 0.235
# model is saved in epoch 16
# ----------------------------------------
# epoch 17 start
# Training loss:
# 	 0: 0.257
# validation loss:
# 	 0: 0.235
# ----------------------------------------
# epoch 18 start
# Training loss:
# 	 0: 0.256
# validation loss:
# 	 0: 0.235
# model is saved in epoch 18
# ----------------------------------------
# epoch 19 start
# Training loss:
# 	 0: 0.254
# validation loss:
# 	 0: 0.233
# model is saved in epoch 19
# ----------------------------------------
# epoch 20 start
# Training loss:
# 	 0: 0.252
# validation loss:
# 	 0: 0.231
# model is saved in epoch 20
# ----------------------------------------
# epoch 21 start
# Training loss:
# 	 0: 0.251
# validation loss:
# 	 0: 0.232
# ----------------------------------------
# epoch 22 start
# Training loss:
# 	 0: 0.250
# validation loss:
# 	 0: 0.232
# ----------------------------------------
# epoch 23 start
# Training loss:
# 	 0: 0.249
# validation loss:
# 	 0: 0.232
# ----------------------------------------
# epoch 24 start
# Training loss:
# 	 0: 0.249
# validation loss:
# 	 0: 0.232
# ----------------------------------------
# epoch 25 start
# Training loss:
# 	 0: 0.249
# validation loss:
# 	 0: 0.232
# ----------------------------------------
# epoch 26 start
# Training loss:
# 	 0: 0.249
# validation loss:
# 	 0: 0.231
# model is saved in epoch 26
# ----------------------------------------
# epoch 27 start
# Training loss:
# 	 0: 0.249
# validation loss:
# 	 0: 0.229
# model is saved in epoch 27
# ----------------------------------------
# epoch 28 start
# Training loss:
# 	 0: 0.247
# validation loss:
# 	 0: 0.229
# ----------------------------------------
# epoch 29 start
# Training loss:
# 	 0: 0.245
# validation loss:
# 	 0: 0.230
# ----------------------------------------
# epoch 30 start
# Training loss:
# 	 0: 0.244
# validation loss:
# 	 0: 0.228
# model is saved in epoch 30
# ----------------------------------------
# epoch 31 start
# Training loss:
# 	 0: 0.242
# validation loss:
# 	 0: 0.228
# model is saved in epoch 31
# ----------------------------------------
# epoch 32 start
# Training loss:
# 	 0: 0.241
# validation loss:
# 	 0: 0.227
# model is saved in epoch 32
# ----------------------------------------
# epoch 33 start
# Training loss:
# 	 0: 0.240
# validation loss:
# 	 0: 0.227
# model is saved in epoch 33
# ----------------------------------------
# epoch 34 start
# Training loss:
# 	 0: 0.240
# validation loss:
# 	 0: 0.227
# ----------------------------------------
# epoch 35 start
# Training loss:
# 	 0: 0.240
# validation loss:
# 	 0: 0.227
# ----------------------------------------
# epoch 36 start
# Training loss:
# 	 0: 0.240
# validation loss:
# 	 0: 0.228
# ----------------------------------------
# epoch 37 start
# Training loss:
# 	 0: 0.240
# validation loss:
# 	 0: 0.227
# model is saved in epoch 37
# ----------------------------------------
# epoch 38 start
# Training loss:
# 	 0: 0.239
# validation loss:
# 	 0: 0.229
# ----------------------------------------
# epoch 39 start
# Training loss:
# 	 0: 0.237
# validation loss:
# 	 0: 0.227
# ----------------------------------------
# epoch 40 start
# Training loss:
# 	 0: 0.235
# validation loss:
# 	 0: 0.226
# model is saved in epoch 40
# ----------------------------------------
# epoch 41 start
# Training loss:
# 	 0: 0.233
# validation loss:
# 	 0: 0.226
# model is saved in epoch 41
# ----------------------------------------
# epoch 42 start
# Training loss:
# 	 0: 0.232
# validation loss:
# 	 0: 0.227
# ----------------------------------------
# epoch 43 start
# Training loss:
# 	 0: 0.231
# validation loss:
# 	 0: 0.226
# ----------------------------------------
# epoch 44 start
# Training loss:
# 	 0: 0.231
# validation loss:
# 	 0: 0.226
# ----------------------------------------
# epoch 45 start
# Training loss:
# 	 0: 0.231
# validation loss:
# 	 0: 0.226
# ----------------------------------------
# epoch 46 start
# Training loss:
# 	 0: 0.231
# validation loss:
# 	 0: 0.226
# model is saved in epoch 46
# ----------------------------------------
# epoch 47 start
# Training loss:
# 	 0: 0.230
# validation loss:
# 	 0: 0.226
# ----------------------------------------
# epoch 48 start
# Training loss:
# 	 0: 0.229
# validation loss:
# 	 0: 0.225
# model is saved in epoch 48
# ----------------------------------------
# epoch 49 start
# Training loss:
# 	 0: 0.227
# validation loss:
# 	 0: 0.225
# model is saved in epoch 49
# ----------------------------------------
# epoch 50 start
# Training loss:
# 	 0: 0.225
# validation loss:
# 	 0: 0.226
# ----------------------------------------
# epoch 51 start
# Training loss:
# 	 0: 0.223
# validation loss:
# 	 0: 0.226
# ----------------------------------------
# epoch 52 start
# Training loss:
# 	 0: 0.222
# validation loss:
# 	 0: 0.226
# ----------------------------------------
# epoch 53 start
# Training loss:
# 	 0: 0.222
# validation loss:
# 	 0: 0.226
# ----------------------------------------
# epoch 54 start
# Training loss:
# 	 0: 0.221
# validation loss:
# 	 0: 0.226
# ----------------------------------------
# epoch 55 start
# Training loss:
# 	 0: 0.221
# validation loss:
# 	 0: 0.226
# ----------------------------------------
# epoch 56 start
# Training loss:
# 	 0: 0.222
# validation loss:
# 	 0: 0.226
# ----------------------------------------
# epoch 57 start
# Training loss:
# 	 0: 0.221
# validation loss:
# 	 0: 0.226
# ----------------------------------------
# epoch 58 start
# Training loss:
# 	 0: 0.219
# validation loss:
# 	 0: 0.226
# ----------------------------------------
# epoch 59 start
# Training loss:
# 	 0: 0.219
# validation loss:
# 	 0: 0.227
# ----------------------------------------
# epoch 60 start
# Training loss:
# 	 0: 0.216
# validation loss:
# 	 0: 0.226
# ----------------------------------------
#
# ----------------------------------------
# Training is stopped by EarlyStopping.
# Training stopped with epoch 60.
# ----------------------------------------

# %%
# check best scores
scores
# Out:
# [tensor(0.2743),
#  tensor(0.2491),
#  tensor(0.2824),
#  tensor(0.2166),
#  tensor(0.2248)]

# %%
# check log file
import pandas as pd
df = pd.read_csv("./trainer_0/log.csv")
df.head()
# Out:
#        Time  LearningRate_1  TrainLoss_1  ValidationLoss_1    rmse_1
# 0  0.039710        0.000090     0.547021          0.434241  0.052936
# 1  0.053729        0.000065     0.491073          0.395146  0.049229
# 2  0.067084        0.000035     0.447982          0.368862  0.046312
# 3  0.080471        0.000010     0.423469          0.355275  0.044848
# 4  0.094623        0.000000     0.413667          0.351610  0.044567
